# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ### Introduction:
#
# This exercise was inspired by this [page](http://chrisalbon.com/python/)
#
# Special thanks to: https://github.com/chrisalbon for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. This is the data given as a dictionary

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
raw_data
# Out:
# {'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
#  'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
#  'company': ['1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '1st',
#   '1st',
#   '2nd',
#   '2nd'],
#  'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
#  'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
#  'origin': ['Arizona',
#   'California',
#   'Texas',
#   'Florida',
#   'Maine',
#   'Iowa',
#   'Alaska',
#   'Washington',
#   'Oregon',
#   'Wyoming',
#   'Louisana',
#   'Georgia'],
#  'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
#  'regiment': ['Nighthawks',
#   'Nighthawks',
#   'Nighthawks',
#   'Nighthawks',
#   'Dragoons',
#   'Dragoons',
#   'Dragoons',
#   'Dragoons',
#   'Scouts',
#   'Scouts',
#   'Scouts',
#   'Scouts'],
#  'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
#  'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345]}

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.
#
# #### Don't forget to include the columns names

# %%
army = pd.DataFrame.from_dict(raw_data)
army.head(3)
# Out:
#    armored  battles company  deaths  deserters      origin  readiness  \
# 0        1        5     1st     523          4     Arizona          1
# 1        0       42     1st      52         24  California          2
# 2        1        2     2nd      25         31       Texas          3
#
#      regiment  size  veterans
# 0  Nighthawks  1045         1
# 1  Nighthawks   957         5
# 2  Nighthawks  1099        62

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
army.set_index('origin')
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Arizona           1        5     1st     523          4          1
# California        0       42     1st      52         24          2
# Texas             1        2     2nd      25         31          3
# Florida           1        2     2nd     616          2          3
# Maine             0        4     1st      43          3          2
# Iowa              1        7     1st     234          4          1
# Alaska            0        8     2nd     523         24          2
# Washington        1        3     2nd      62         31          3
# Oregon            0        4     1st      62          2          2
# Wyoming           0        7     1st      73          3          1
# Louisana          1        8     2nd      37          2          2
# Georgia           1        9     2nd      35          3          3
#
#               regiment  size  veterans
# origin
# Arizona     Nighthawks  1045         1
# California  Nighthawks   957         5
# Texas       Nighthawks  1099        62
# Florida     Nighthawks  1400        26
# Maine         Dragoons  1592        73
# Iowa          Dragoons  1006        37
# Alaska        Dragoons   987       949
# Washington    Dragoons   849        48
# Oregon          Scouts   973        48
# Wyoming         Scouts  1005       435
# Louisana        Scouts  1099        63
# Georgia         Scouts  1523       345

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
army.veterans
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
army[['veterans', 'deaths']]
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
army.columns
# Out:
# Index([u'armored', u'battles', u'company', u'deaths', u'deserters', u'origin',
#        u'readiness', u'regiment', u'size', u'veterans'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.loc[['Maine','Alaska'], ["deaths", "size", "deserters"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-02955a333486> in <module>()
# ----> 1 army.loc[['Maine','Alaska'], ["deaths", "size", "deserters"]]
#
# /Users/allash/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /Users/allash/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     787
#     788         # no multi-index, so validate all of the indexers
# --> 789         self._has_valid_tuple(tup)
#     790
#     791         # ugly hack for GH #836
#
# /Users/allash/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
#     140             if i >= self.obj.ndim:
#     141                 raise IndexingError('Too many indexers')
# --> 142             if not self._has_valid_type(k, i):
#     143                 raise ValueError("Location based indexing can only have [%s] "
#     144                                  "types" % self._valid_types)
#
# /Users/allash/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1377
#    1378                 raise KeyError("None of [%s] are in the [%s]" %
# -> 1379                                (key, self.obj._get_axis_name(axis)))
#    1380
#    1381             return True
#
# KeyError: "None of [['Maine', 'Alaska']] are in the [index]"

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
army.iloc[3:7, 3:6]
# Out:
#    deaths  deserters   origin
# 3     616          2  Florida
# 4      43          3    Maine
# 5     234          4     Iowa
# 6     523         24   Alaska

# %% [markdown]
# ### Step 10. Select every row after the fourth row

# %%
army.iloc[3:]
# Out:
#     armored  battles company  deaths  deserters      origin  readiness  \
# 3         1        2     2nd     616          2     Florida          3
# 4         0        4     1st      43          3       Maine          2
# 5         1        7     1st     234          4        Iowa          1
# 6         0        8     2nd     523         24      Alaska          2
# 7         1        3     2nd      62         31  Washington          3
# 8         0        4     1st      62          2      Oregon          2
# 9         0        7     1st      73          3     Wyoming          1
# 10        1        8     2nd      37          2    Louisana          2
# 11        1        9     2nd      35          3     Georgia          3
#
#       regiment  size  veterans
# 3   Nighthawks  1400        26
# 4     Dragoons  1592        73
# 5     Dragoons  1006        37
# 6     Dragoons   987       949
# 7     Dragoons   849        48
# 8       Scouts   973        48
# 9       Scouts  1005       435
# 10      Scouts  1099        63
# 11      Scouts  1523       345

# %% [markdown]
# ### Step 11. Select every row up to the 4th row

# %%
army.iloc[0:3]
# Out:
#    armored  battles company  deaths  deserters      origin  readiness  \
# 0        1        5     1st     523          4     Arizona          1
# 1        0       42     1st      52         24  California          2
# 2        1        2     2nd      25         31       Texas          3
#
#      regiment  size  veterans
# 0  Nighthawks  1045         1
# 1  Nighthawks   957         5
# 2  Nighthawks  1099        62

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
army.iloc[:, 3:7]
# Out:
#     deaths  deserters      origin  readiness
# 0      523          4     Arizona          1
# 1       52         24  California          2
# 2       25         31       Texas          3
# 3      616          2     Florida          3
# 4       43          3       Maine          2
# 5      234          4        Iowa          1
# 6      523         24      Alaska          2
# 7       62         31  Washington          3
# 8       62          2      Oregon          2
# 9       73          3     Wyoming          1
# 10      37          2    Louisana          2
# 11      35          3     Georgia          3

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
army[army.deaths > 50]
# Out:
#    armored  battles company  deaths  deserters      origin  readiness  \
# 0        1        5     1st     523          4     Arizona          1
# 1        0       42     1st      52         24  California          2
# 3        1        2     2nd     616          2     Florida          3
# 5        1        7     1st     234          4        Iowa          1
# 6        0        8     2nd     523         24      Alaska          2
# 7        1        3     2nd      62         31  Washington          3
# 8        0        4     1st      62          2      Oregon          2
# 9        0        7     1st      73          3     Wyoming          1
#
#      regiment  size  veterans
# 0  Nighthawks  1045         1
# 1  Nighthawks   957         5
# 3  Nighthawks  1400        26
# 5    Dragoons  1006        37
# 6    Dragoons   987       949
# 7    Dragoons   849        48
# 8      Scouts   973        48
# 9      Scouts  1005       435

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
army[(army.deaths > 500) | (army.deaths < 50)]
# Out:
#     armored  battles company  deaths  deserters    origin  readiness  \
# 0         1        5     1st     523          4   Arizona          1
# 2         1        2     2nd      25         31     Texas          3
# 3         1        2     2nd     616          2   Florida          3
# 4         0        4     1st      43          3     Maine          2
# 6         0        8     2nd     523         24    Alaska          2
# 10        1        8     2nd      37          2  Louisana          2
# 11        1        9     2nd      35          3   Georgia          3
#
#       regiment  size  veterans
# 0   Nighthawks  1045         1
# 2   Nighthawks  1099        62
# 3   Nighthawks  1400        26
# 4     Dragoons  1592        73
# 6     Dragoons   987       949
# 10      Scouts  1099        63
# 11      Scouts  1523       345

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
army[army.regiment != 'Dragoons']
# Out:
#     armored  battles company  deaths  deserters      origin  readiness  \
# 0         1        5     1st     523          4     Arizona          1
# 1         0       42     1st      52         24  California          2
# 2         1        2     2nd      25         31       Texas          3
# 3         1        2     2nd     616          2     Florida          3
# 8         0        4     1st      62          2      Oregon          2
# 9         0        7     1st      73          3     Wyoming          1
# 10        1        8     2nd      37          2    Louisana          2
# 11        1        9     2nd      35          3     Georgia          3
#
#       regiment  size  veterans
# 0   Nighthawks  1045         1
# 1   Nighthawks   957         5
# 2   Nighthawks  1099        62
# 3   Nighthawks  1400        26
# 8       Scouts   973        48
# 9       Scouts  1005       435
# 10      Scouts  1099        63
# 11      Scouts  1523       345

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
#army[(army.origin == 'Texas') | (army.origin == 'Arizona')]
army.ix[['Arizona', 'Texas']]
# Out:
#          armored  battles company  deaths  deserters origin  readiness  \
# Arizona      NaN      NaN     NaN     NaN        NaN    NaN        NaN
# Texas        NaN      NaN     NaN     NaN        NaN    NaN        NaN
#
#         regiment  size  veterans
# Arizona      NaN   NaN       NaN
# Texas        NaN   NaN       NaN

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
army.ix[['Arizona'], 'deaths']
# Out:
# Arizona   NaN
# Name: deaths, dtype: float64

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
army.ix[2, 'deaths']
# Out:
# 25
